# %%
3 + 5
# Out:
# 8

# %%
4 * 3
# Out:
# 12

# %%
900 / 7
# Out:
# 128.57142857142858

# %%
10 - 100
# Out:
# -90

# %%
5 * 5 * 5 * 5 * 5
# Out:
# 3125

# %%
5*5*5*5*5
# Out:
# 3125

# %%
age = 50

# %%
age
# Out:
# 50

# %%
age * 5
# Out:
# 250

# %%
age / 2
# Out:
# 25.0

# %%
# data type

# %%
type(10)
# Out:
# int

# %%
type(age * 5)
# Out:
# int

# %%
# int -> integer

# %%
x = -100

# %%
type(x)
# Out:
# int

# %%
type (3.14)
# Out:
# float

# %%
#float -> floating point

# %%
pi = 3.14

# %%
pi * 2
# Out:
# 6.28

# %%
x
# Out:
# -100

# %%
x + pi
# Out:
# -96.86

# %%
x / pi
# Out:
# -31.84713375796178

# %%
x = 10

# %%
x = 20

# %%
x + 10
# Out:
# 30

# %%
myFloat = 1.423241

# %%
type(myFloat)
# Out:
# float

# %%
# camelCase
# snake_case
